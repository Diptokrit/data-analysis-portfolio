# %%
import pandas as pd                 #for data handling 
import matplotlib.pyplot as plt     #for creation of charts
import seaborn as sns               #for better visual styles

plt.style.use(ggplot)               #default chart style
